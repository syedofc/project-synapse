# %%
# ==============================================================================
# File 10a: 10_notebooks/10a_0_Data_Exploration.ipynb
# Purpose: To explore and visualize our datasets.
# ==============================================================================

# %% [markdown]
# # Notebook 0: Data Exploration
# 
# This notebook is for loading, visualizing, and understanding our two primary datasets: CIFAR-100 and 20 Newsgroups.

# %%
import os
import sys
import matplotlib.pyplot as plt
import numpy as np

# Add project root to path to allow importing our modules
sys.path.append(os.path.abspath(os.path.join(os.path.dirname('__file__'), '..')))

from data import a_cifar100_loader, b_20newsgroups_loader

# %% [markdown]
# ## 1. CIFAR-100 Visualization

# %%
# Load CIFAR-100 data
cifar_train_loader, _, _, _ = a_cifar100_loader.get_cifar100_loaders(
    data_path="../datasets/cifar100", # Assumes notebooks are run from `synapse/notebooks`
    batch_size=10, 
    num_workers=2
)

# Get one batch of images
dataiter = iter(cifar_train_loader)
images, labels = next(dataiter)

# Function to show an image
def imshow(img):
    img = img / 2 + 0.5  # Unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

print("Displaying a batch of 10 CIFAR-100 images...")
imshow(torchvision.utils.make_grid(images))
# Note: Labels are just numbers here; you would need a mapping to get class names.

# %% [markdown]
# ## 2. 20 Newsgroups Exploration

# %%
# We need to fetch the raw data again to see the text
from sklearn.datasets import fetch_20newsgroups

print("Fetching raw 20 Newsgroups data...")
newsgroups_train = fetch_20newsgroups(
    subset='train', remove=('headers', 'footers', 'quotes'), shuffle=True, random_state=42
)

# Print a few samples
print("\n--- Sample 20 Newsgroups Posts ---")
for i in range(3):
    print(f"\nSample {i+1} | Category: {newsgroups_train.target_names[newsgroups_train.target[i]]}")
    print("-" * 40)
    print(newsgroups_train.data[i][:500] + "...")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 20
#      17 # Add project root to path to allow importing our modules
#      18 sys.path.append(os.path.abspath(os.path.join(os.path.dirname('__file__'), '..')))
# ---> 20 from data import a_cifar100_loader, b_20newsgroups_loader
#      22 # %% [markdown]
#      23 # ## 1. CIFAR-100 Visualization
#      24
#      25 # %%
#      26 # Load CIFAR-100 data
#      27 cifar_train_loader, _, _, _ = a_cifar100_loader.get_cifar100_loaders(
#      28     data_path="../datasets/cifar100", # Assumes notebooks are run from `synapse/notebooks`
#      29     batch_size=10,
#      30     num_workers=2
#      31 )
#
# ImportError: cannot import name 'a_cifar100_loader' from 'data' (unknown location)
