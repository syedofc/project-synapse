# %%
# ==============================================================================
# File 10c: 10_notebooks/10c_2_Full_System_Analysis.ipynb
# Purpose: To load a fully trained model and analyze its behavior.
# NOTE: This is a skeleton, as it requires a trained model checkpoint.
# ==============================================================================

# %% [markdown]
# # Notebook 2: Full System Analysis
# 
# This notebook is for deep analysis of a **fully trained** `SynapseModel`.
# 
# **Prerequisites:** You must have a saved model checkpoint (`.pth` file) from a training run.

# %%
# import os
# import sys
# import torch
# import yaml
# import matplotlib.pyplot as plt

# sys.path.append(os.path.abspath(os.path.join(os.path.dirname('__file__'), '..')))

# from src.e_synapse_model import SynapseModel

# %% [markdown]
# ## 1. Load Model and Config

# %%
# CHECKPOINT_PATH = "path/to/your/best_model.pth"
# CONFIG_PATH = "path/to/the/config_used_for_training.yaml"

# print("--- This is a skeleton for analysis ---")
# print("1. Load the config file used for training.")
# print("2. Initialize the SynapseModel with that config.")
# print(f"3. Load the trained weights from {CHECKPOINT_PATH}")
# # model.load_state_dict(torch.load(CHECKPOINT_PATH))
# # model.eval()

# %% [markdown]
# ## 2. Analyze Weight Generation
# 
# A key insight is to see how the generated weights differ across tasks.

# %%
# print("\n4. Generate weights for different tasks (e.g., Task 0 vs Task 1).")
# # task_0_id = torch.tensor([0])
# # task_1_id = torch.tensor([1])
# # context = model.monitor.get_context()
# # weights_0 = model.weaver(task_0_id, context)
# # weights_1 = model.weaver(task_1_id, context)

# print("5. Visualize the difference in a specific layer's weights.")
# # w0 = weights_0['layers.0.weight'].detach().cpu().numpy()
# # w1 = weights_1['layers.0.weight'].detach().cpu().numpy()
# # difference = w0 - w1

# # plt.figure(figsize=(12, 5))
# # plt.subplot(1, 3, 1)
# # plt.title("Task 0 Weights (Layer 0)")
# # plt.imshow(w0, cmap='viridis')
# # plt.subplot(1, 3, 2)
# # plt.title("Task 1 Weights (Layer 0)")
# # plt.imshow(w1, cmap='viridis')
# # plt.subplot(1, 3, 3)
# # plt.title("Difference (W0 - W1)")
# # plt.imshow(difference, cmap='coolwarm')
# # plt.show()
